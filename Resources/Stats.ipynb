# %% [markdown]
# # **Chicago Crime Data vs Weather - 2016**

# %%
import pandas as pd
import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crime_categories = pd.read_csv('CrimeCategories.csv')
weather = pd.read_csv('temperature_2016.csv')
crime = pd.read_csv('Crime_data_2016.csv')

# %%
crime['Month']= pd.DatetimeIndex(crime['ShortDate']).month
crime.head()
# Out:
#    Unnamed: 0 Case Number          Primary Type              Date   ShortDate  \
# 0      646621    JA119772                 THEFT  12/31/2016 23:59  12/31/2016
# 1      646622    JA100016               BATTERY  12/31/2016 23:58  12/31/2016
# 2      646623    JA100012               BATTERY  12/31/2016 23:55  12/31/2016
# 3      646624    JA100027  LIQUOR LAW VIOLATION  12/31/2016 23:55  12/31/2016
# 4      646625    JA100839       CRIMINAL DAMAGE  12/31/2016 23:54  12/31/2016
#
#    Hour  Year  DateConvert  Month
# 0    23  2016      4270523     12
# 1    23  2016      4270523     12
# 2    23  2016      4270523     12
# 3    23  2016      4270523     12
# 4    23  2016      4270523     12

# %% [markdown]
# #### Here we merge our weather and crime data then convert the ShortDate back into datetime format

# %%
df = pd.merge(weather, crime, on =['ShortDate','Hour'])
df['ShortDate'] = pd.to_datetime(df['ShortDate'],format='%m/%d/%Y')
print(df['ShortDate'].dtype)
# Out:
# datetime64[ns]

# %%
crime_categories.rename(columns={'crime primary type':'Primary Type'},inplace=True)
combined_df = df.merge(crime_categories, how='inner',on='Primary Type')
combined_df
# Out:
#                 datetime  ShortDate  Hour  DateConvert_x     Chicago  \
# 0          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 1          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 2          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 3          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 4          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 5          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 6          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 7          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 8          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 9          1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 10         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 11         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 12         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 13         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 14         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 15         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 16         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 17         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 18         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 19         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 20         1/1/2016 0:00 2016-01-01     0         423700  269.470523
# 21         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 22         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 23         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 24         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 25         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 26         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 27         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 28         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# 29         1/1/2016 1:00 2016-01-01     1         423701  269.010000
# ...                  ...        ...   ...            ...         ...
# 269051   1/29/2016 15:00 2016-01-29    15        4239815  269.480000
# 269052     2/2/2016 7:00 2016-02-02     7         424027  273.070000
# 269053    2/6/2016 11:00 2016-02-06    11        4240611  270.120000
# 269054    2/10/2016 9:00 2016-02-10     9         424109  262.600000
# 269055    2/13/2016 0:00 2016-02-13     0         424130  266.077428
# 269056   1/30/2016 17:00 2016-01-30    17        4239917  277.089804
# 269057   6/25/2016 23:00 2016-06-25    23        4254623  304.350000
# 269058   6/25/2016 23:00 2016-06-25    23        4254623  304.350000
# 269059  12/13/2016 10:00 2016-12-13    10        4271710  266.720000
# 269060     2/1/2016 0:00 2016-02-01     0         424010  278.277205
# 269061     3/1/2016 0:00 2016-03-01     0         424300  276.760000
# 269062   4/24/2016 17:00 2016-04-24    17        4248417  294.580000
# 269063   5/31/2016 13:00 2016-05-31    13        4252113  295.750000
# 269064   7/12/2016 13:00 2016-07-12    13        4256313  298.490000
# 269065    8/1/2016 10:00 2016-08-01    10        4258310  291.240000
# 269066    8/30/2016 6:00 2016-08-30     6         426126  295.390000
# 269067    9/3/2016 15:00 2016-09-03    15        4261615  294.850000
# 269068     9/4/2016 0:00 2016-09-04     0         426170  294.080000
# 269069   9/24/2016 12:00 2016-09-24    12        4263712  291.790000
# 269070   10/12/2016 8:00 2016-10-12     8         426558  290.074000
# 269071   2/25/2016 16:00 2016-02-25    16        4242516  274.200000
# 269072   5/12/2016 12:00 2016-05-12    12        4250212  289.870000
# 269073    5/13/2016 7:00 2016-05-13     7         425037  284.130000
# 269074   5/28/2016 16:00 2016-05-28    16        4251816  297.360000
# 269075   6/16/2016 15:00 2016-06-16    15        4253715  293.880000
# 269076    6/30/2016 9:00 2016-06-30     9         425519  286.650000
# 269077     8/5/2016 4:00 2016-08-05     4         425874  298.340000
# 269078    8/19/2016 5:00 2016-08-19     5         426015  295.670000
# 269079   8/28/2016 18:00 2016-08-28    18        4261018  300.390000
# 269080   9/11/2016 17:00 2016-09-11    17        4262417  295.590000
#
#         Temp_Farenheit  Unnamed: 0 Case Number              Primary Type  \
# 0            25.376941      915396    HZ100075                   BATTERY
# 1            25.376941      915400    HZ100077                   BATTERY
# 2            25.376941      915401    HZ100044                   BATTERY
# 3            25.376941      915403    HZ122194                   BATTERY
# 4            25.376941      915404    HZ100062                   BATTERY
# 5            25.376941      915407    HZ100032                   BATTERY
# 6            25.376941      915413    HZ103526                   BATTERY
# 7            25.376941      915414    HZ100088                   BATTERY
# 8            25.376941      915415    HZ100039                   BATTERY
# 9            25.376941      915416    HZ101144                   BATTERY
# 10           25.376941      915419    HZ100040                   BATTERY
# 11           25.376941      915421    HZ100013                   BATTERY
# 12           25.376941      915424    HZ100056                   BATTERY
# 13           25.376941      915427    HZ100018                   BATTERY
# 14           25.376941      915428    HZ100121                   BATTERY
# 15           25.376941      915429    HZ102836                   BATTERY
# 16           25.376941      915431    HZ100022                   BATTERY
# 17           25.376941      915432    HZ100035                   BATTERY
# 18           25.376941      915437    HZ100014                   BATTERY
# 19           25.376941      915440    HZ100015                   BATTERY
# 20           25.376941      915581    HZ107053                   BATTERY
# 21           24.548000      915344    HZ100526                   BATTERY
# 22           24.548000      915346    HZ100082                   BATTERY
# 23           24.548000      915347    HZ100105                   BATTERY
# 24           24.548000      915348    HZ100097                   BATTERY
# 25           24.548000      915349    HZ100091                   BATTERY
# 26           24.548000      915351    HZ100789                   BATTERY
# 27           24.548000      915353    HZ100101                   BATTERY
# 28           24.548000      915354    HZ100555                   BATTERY
# 29           24.548000      915355    HZ100092                   BATTERY
# ...                ...         ...         ...                       ...
# 269051       25.394000      896802    HZ133234            NON - CRIMINAL
# 269052       31.856000      894134    HZ137710            NON - CRIMINAL
# 269053       26.546000      891363    HZ142394            NON - CRIMINAL
# 269054       13.010000      889037    HZ146595            NON - CRIMINAL
# 269055       19.269371      887373    HZ149851            NON - CRIMINAL
# 269056       39.091647      895977    HZ134665  OTHER NARCOTIC VIOLATION
# 269057       88.160000      789687    HZ323642  OTHER NARCOTIC VIOLATION
# 269058       88.160000      789693    HZ323631  OTHER NARCOTIC VIOLATION
# 269059       20.426000      658754    HZ550015  OTHER NARCOTIC VIOLATION
# 269060       41.228968      895026    HZ182313         HUMAN TRAFFICKING
# 269061       38.498000      876353    HZ192829         HUMAN TRAFFICKING
# 269062       70.574000      837656    HZ241210         HUMAN TRAFFICKING
# 269063       72.680000      810137    HZ318594         HUMAN TRAFFICKING
# 269064       77.612000      776658    HZ346030         HUMAN TRAFFICKING
# 269065       64.562000      760608    HZ415939         HUMAN TRAFFICKING
# 269066       72.032000      737455    HZ413034         HUMAN TRAFFICKING
# 269067       71.060000      733749    HZ419320         HUMAN TRAFFICKING
# 269068       69.674000      733388    HZ445465         HUMAN TRAFFICKING
# 269069       65.552000      717294    HZ453182         HUMAN TRAFFICKING
# 269070       62.463200      703948    HZ512953         HUMAN TRAFFICKING
# 269071       33.890000      879336    HZ164940          PUBLIC INDECENCY
# 269072       62.096000      824860    HZ261462          PUBLIC INDECENCY
# 269073       51.764000      824276    HZ262482          PUBLIC INDECENCY
# 269074       75.578000      812418    HZ283654          PUBLIC INDECENCY
# 269075       69.314000      797236    HZ310340          PUBLIC INDECENCY
# 269076       56.300000      786349    HZ338168          PUBLIC INDECENCY
# 269077       77.342000      757560    HZ378869          PUBLIC INDECENCY
# 269078       72.536000      746265    HZ398178          PUBLIC INDECENCY
# 269079       81.032000      738661    HZ411008          PUBLIC INDECENCY
# 269080       72.392000      727439    HZ429838          PUBLIC INDECENCY
#
#                     Date  Year  DateConvert_y  Month     bucket
# 0          1/1/2016 0:55  2016         423700      1   Personal
# 1          1/1/2016 0:46  2016         423700      1   Personal
# 2          1/1/2016 0:45  2016         423700      1   Personal
# 3          1/1/2016 0:45  2016         423700      1   Personal
# 4          1/1/2016 0:45  2016         423700      1   Personal
# 5          1/1/2016 0:36  2016         423700      1   Personal
# 6          1/1/2016 0:30  2016         423700      1   Personal
# 7          1/1/2016 0:30  2016         423700      1   Personal
# 8          1/1/2016 0:30  2016         423700      1   Personal
# 9          1/1/2016 0:30  2016         423700      1   Personal
# 10         1/1/2016 0:30  2016         423700      1   Personal
# 11         1/1/2016 0:25  2016         423700      1   Personal
# 12         1/1/2016 0:23  2016         423700      1   Personal
# 13         1/1/2016 0:20  2016         423700      1   Personal
# 14         1/1/2016 0:15  2016         423700      1   Personal
# 15         1/1/2016 0:15  2016         423700      1   Personal
# 16         1/1/2016 0:14  2016         423700      1   Personal
# 17         1/1/2016 0:12  2016         423700      1   Personal
# 18         1/1/2016 0:05  2016         423700      1   Personal
# 19         1/1/2016 0:02  2016         423700      1   Personal
# 20         1/1/2016 0:01  2016         423700      1   Personal
# 21         1/1/2016 1:45  2016         423701      1   Personal
# 22         1/1/2016 1:37  2016         423701      1   Personal
# 23         1/1/2016 1:37  2016         423701      1   Personal
# 24         1/1/2016 1:35  2016         423701      1   Personal
# 25         1/1/2016 1:30  2016         423701      1   Personal
# 26         1/1/2016 1:30  2016         423701      1   Personal
# 27         1/1/2016 1:30  2016         423701      1   Personal
# 28         1/1/2016 1:30  2016         423701      1   Personal
# 29         1/1/2016 1:30  2016         423701      1   Personal
# ...                  ...   ...            ...    ...        ...
# 269051   1/29/2016 15:30  2016        4237015      1      Other
# 269052     2/2/2016 7:00  2016         424017      2      Other
# 269053    2/6/2016 11:20  2016        4240111      2      Other
# 269054    2/10/2016 9:07  2016         424019      2      Other
# 269055    2/13/2016 0:11  2016         424010      2      Other
# 269056   1/30/2016 17:48  2016        4237017      1  Statutory
# 269057   6/25/2016 23:45  2016        4252223      6  Statutory
# 269058   6/25/2016 23:22  2016        4252223      6  Statutory
# 269059  12/13/2016 10:30  2016        4270510     12  Statutory
# 269060     2/1/2016 0:01  2016         424010      2   Personal
# 269061     3/1/2016 0:00  2016         424300      3   Personal
# 269062   4/24/2016 17:00  2016        4246117      4   Personal
# 269063   5/31/2016 13:00  2016        4249113      5   Personal
# 269064   7/12/2016 13:00  2016        4255213      7   Personal
# 269065    8/1/2016 10:00  2016        4258310      8   Personal
# 269066    8/30/2016 6:02  2016         425836      8   Personal
# 269067    9/3/2016 15:15  2016        4261415      9   Personal
# 269068     9/4/2016 0:00  2016         426140      9   Personal
# 269069   9/24/2016 12:00  2016        4261412      9   Personal
# 269070   10/12/2016 8:00  2016         426448     10   Personal
# 269071   2/25/2016 16:40  2016        4240116      2   Personal
# 269072   5/12/2016 12:15  2016        4249112      5   Personal
# 269073    5/13/2016 7:34  2016         424917      5   Personal
# 269074   5/28/2016 16:22  2016        4249116      5   Personal
# 269075   6/16/2016 15:40  2016        4252215      6   Personal
# 269076    6/30/2016 9:04  2016         425229      6   Personal
# 269077     8/5/2016 4:10  2016         425834      8   Personal
# 269078    8/19/2016 5:10  2016         425835      8   Personal
# 269079   8/28/2016 18:40  2016        4258318      8   Personal
# 269080   9/11/2016 17:13  2016        4261417      9   Personal
#
# [269081 rows x 14 columns]

# %% [markdown]
# # Need to work on the stats piece here
# * Take the average of the population
# * Take the average per min and max bins and also for 25%, 50%, 75%

# %% [markdown]
# #### Need to set up bins to break our data up into smaller groups. First determine max and min to determine bin grouping

# %%
maxTemp = combined_df['Temp_Farenheit'].max()
minTemp = combined_df['Temp_Farenheit'].min()
print(f"The max temp is: {maxTemp}\nThe min temp is {minTemp}")
# Out:
# The max temp is: 91.634
# The min temp is -9.777999999999999

# %% [markdown]
# #### Remove duplicate columns to keep dataframe clean

# %%
del combined_df['DateConvert_x']
del combined_df['Unnamed: 0']
del combined_df['DateConvert_y']
del combined_df['Date']

# %%
combined_df.head()
# Out:
#         datetime  ShortDate  Hour     Chicago  Temp_Farenheit Case Number  \
# 0  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100075
# 1  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100077
# 2  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100044
# 3  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ122194
# 4  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100062
#
#   Primary Type  Year  Month    bucket
# 0      BATTERY  2016      1  Personal
# 1      BATTERY  2016      1  Personal
# 2      BATTERY  2016      1  Personal
# 3      BATTERY  2016      1  Personal
# 4      BATTERY  2016      1  Personal

# %%
bins = [-15,-5,5,15,25,35,45,55,65,75,85,95]
tempName = ['< -5 degrees','-5 to 4.9 degrees','5 to 14.9 degrees','15 to 24.9 degrees','25 to 34.9 degrees','35 to 44.9 degrees'\
            ,'45 to 54.9 degrees','55 to 64.9 degrees','65 to 74.9 degrees','75 to 84.9 degrees','85 to 95 degrees']
combined_df['TempBucket'] = pd.cut(combined_df['Temp_Farenheit'],bins,labels=tempName)
combined_df.head()
# Out:
#         datetime  ShortDate  Hour     Chicago  Temp_Farenheit Case Number  \
# 0  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100075
# 1  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100077
# 2  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100044
# 3  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ122194
# 4  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100062
#
#   Primary Type  Year  Month    bucket          TempBucket
# 0      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 1      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 2      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 3      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 4      BATTERY  2016      1  Personal  25 to 34.9 degrees

# %%
# comb_group = combined_df.groupby('bucket').agg('Case Number').count()
# comb_group = comb_group.to_frame().reset_index()
# comb_group
# comb_group.reset_index(drop=False,inplace=True)
# comb_group
# tips = sns.load_dataset("tips")
# sns.catplot(x="bucket", y="Temp_Farenheit", kind="box",data=combined_df);
# sns.catplot(x="day", y="total_bill", kind="box", data=combined_df);
# sns.catplot(x="bucket", y="Temp_Farenheit", kind="swarm", data=combined_df);

# %% [markdown]
# #### Prep data for scatter plot of total crime over temp

# %%
scatter_df = pd.pivot_table(combined_df,values='Case Number', index='Temp_Farenheit',columns='bucket',  aggfunc=lambda x: len(x.unique()),fill_value=0)
scat_x = scatter_df.index.tolist()

Oth_scat = scatter_df[scatter_df.columns[0]]
Pers_scat = scatter_df[scatter_df.columns[1]]
Prop_scat = scatter_df[scatter_df.columns[2]]
Stat_scat = scatter_df[scatter_df.columns[3]]

# # scatter_df.to_csv(r'C:\Users\tepa7\Desktop\File Name.csv')
# ax = plt.plot(kind='scatter', x=scat_x, y=Oth_scat)
# plt.plot(scat_x,PersDF)
fig, ax = plt.subplots()
ax.plot(scat_x, Prop_scat, color = 'orange',linestyle='', marker='o', label = 'Property')
ax.plot(scat_x, Pers_scat, color = 'blue',linestyle='', marker='o',label = 'Personal')
ax.plot(scat_x, Stat_scat, color = 'green', linestyle='', marker='o', label = 'Statutory')
ax.plot(scat_x, Oth_scat, color = 'red', linestyle='', marker='o',label = 'Others')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xlabel("Temperature")
plt.ylabel("Crime count")
plt.title('Temperature and Crime count by types')
# Out:
# Text(0.5, 1.0, 'Temperature and Crime count by types')

# %% [markdown]
# #### Updated the y-limit to remove the one outlier of 800+ crime commited

# %%
fig, ax = plt.subplots()
ax.plot(scat_x, Prop_scat, color = 'orange',linestyle='', marker='o', label = 'Property')
ax.plot(scat_x, Pers_scat, color = 'blue',linestyle='', marker='o',label = 'Personal')
ax.plot(scat_x, Stat_scat, color = 'green', linestyle='', marker='o', label = 'Statutory')
ax.plot(scat_x, Oth_scat, color = 'red', linestyle='', marker='o',label = 'Others')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xlabel("Temperature")
plt.ylabel("Crime count")
plt.title('Temperature and Crime count by types')
ax.set_ylim(-5,400)
# Out:
# (-5, 400)

# %% [markdown]
# #### Create the pivot table and print to determine the column indices so we can extract a series for our line chart

# %%
buckets = pd.pivot_table(combined_df,values='Case Number', index='TempBucket',columns='bucket',  aggfunc=lambda x: len(x.unique()),fill_value=0)
buckets.head()

buckets = pd.pivot_table(combined_df,values='Case Number', index='TempBucket',columns='bucket',  aggfunc=lambda x: len(x.unique()),fill_value=0)
buckets.head()
# Out:
# bucket              Other  Personal  Property  Statutory
# TempBucket
# < -5 degrees           51        79       180          8
# -5 to 4.9 degrees     179       520      1392        141
# 5 to 14.9 degrees     391      1310      2937        306
# 15 to 24.9 degrees   1005      3233      7532        902
# 25 to 34.9 degrees   2439      8613     19144       2249

# %%
OthDF = buckets[buckets.columns[0]]
PersDF = buckets[buckets.columns[1]]
PropDF = buckets[buckets.columns[2]]
StatDF = buckets[buckets.columns[3]]
x = buckets.index.tolist()

# %%
ax = buckets[['Other','Personal','Property','Statutory']].plot(kind='bar', stacked=True)
plt.xticks(rotation=45)
ax.set_title('Types of Crime across Temperature')
ax.legend(['Other','Personal','Property','Statutory']);

# %%
combined_df.head()
# Out:
#         datetime  ShortDate  Hour     Chicago  Temp_Farenheit Case Number  \
# 0  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100075
# 1  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100077
# 2  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100044
# 3  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ122194
# 4  1/1/2016 0:00 2016-01-01     0  269.470523       25.376941    HZ100062
#
#   Primary Type  Year  Month    bucket          TempBucket
# 0      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 1      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 2      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 3      BATTERY  2016      1  Personal  25 to 34.9 degrees
# 4      BATTERY  2016      1  Personal  25 to 34.9 degrees

# %%
buckets_pers = pd.pivot_table(combined_df[combined_df['bucket']=='Personal'],values='Case Number', index='TempBucket',columns='Primary Type',  aggfunc=lambda x: len(x.unique()),fill_value=0)
print(buckets_pers.columns)

# buckets = pd.pivot_table(combined_df,values='Case Number', index='TempBucket',columns='bucket',  aggfunc=lambda x: len(x.unique()),fill_value=0)
# buckets.head()
# Out:
# Index(['ASSAULT', 'BATTERY', 'CRIM SEXUAL ASSAULT', 'HOMICIDE',
#        'HUMAN TRAFFICKING', 'INTIMIDATION', 'KIDNAPPING', 'OBSCENITY',
#        'OFFENSE INVOLVING CHILDREN', 'PUBLIC INDECENCY', 'SEX OFFENSE',
#        'STALKING'],
#       dtype='object', name='Primary Type')

# %%
OthDF
# Out:
# TempBucket
# < -5 degrees            51
# -5 to 4.9 degrees      179
# 5 to 14.9 degrees      391
# 15 to 24.9 degrees    1005
# 25 to 34.9 degrees    2439
# 35 to 44.9 degrees    2840
# 45 to 54.9 degrees    2779
# 55 to 64.9 degrees    3016
# 65 to 74.9 degrees    4122
# 75 to 84.9 degrees    2552
# 85 to 95 degrees       598
# Name: Other, dtype: int64

# %%
PersDF
# Out:
# TempBucket
# < -5 degrees             79
# -5 to 4.9 degrees       520
# 5 to 14.9 degrees      1310
# 15 to 24.9 degrees     3233
# 25 to 34.9 degrees     8613
# 35 to 44.9 degrees     9964
# 45 to 54.9 degrees    10022
# 55 to 64.9 degrees    11476
# 65 to 74.9 degrees    16313
# 75 to 84.9 degrees    11209
# 85 to 95 degrees       2507
# Name: Personal, dtype: int64

# %%
PropDF
# Out:
# TempBucket
# < -5 degrees            180
# -5 to 4.9 degrees      1392
# 5 to 14.9 degrees      2937
# 15 to 24.9 degrees     7532
# 25 to 34.9 degrees    19144
# 35 to 44.9 degrees    21098
# 45 to 54.9 degrees    20642
# 55 to 64.9 degrees    24153
# 65 to 74.9 degrees    33111
# 75 to 84.9 degrees    21127
# 85 to 95 degrees       4601
# Name: Property, dtype: int64

# %%
StatDF
# Out:
# TempBucket
# < -5 degrees             8
# -5 to 4.9 degrees      141
# 5 to 14.9 degrees      306
# 15 to 24.9 degrees     902
# 25 to 34.9 degrees    2249
# 35 to 44.9 degrees    2511
# 45 to 54.9 degrees    2634
# 55 to 64.9 degrees    2574
# 65 to 74.9 degrees    3393
# 75 to 84.9 degrees    2538
# 85 to 95 degrees       657
# Name: Statutory, dtype: int64

# %%
plt.plot(x,OthDF,label = 'Others')
plt.plot(x,PersDF,label = 'Personal' )
plt.plot(x,PropDF,label = 'Property')
plt.plot(x,StatDF,label = 'Statutory')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)
plt.title('Temperature and Crime count by types')

plt.tight_layout()

# %%
fig, ax = plt.subplots(2,2, figsize = (10,5))
ax[0,0].plot(x,PersDF)
ax[0, 0].set_title('Personal')
ax[0, 0].set_rotation(45)

ax[1,0].plot(x,PropDF)
ax[1, 0].set_title('Property')
plt.xticks(rotation=45)

ax[0,1].plot(x,StatDF)
ax[0, 1].set_title('Statutory')
plt.xticks(rotation=45)

ax[1,1].plot(x,OthDF)
ax[1, 1].set_title('Other')
plt.xticks(rotation=45)

# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-275ba4705fd0> in <module>
#       2 ax[0,0].plot(x,PersDF)
#       3 ax[0, 0].set_title('Personal')
# ----> 4 ax[0, 0].set_rotation(45)
#       5
#       6 ax[1,0].plot(x,PropDF)
#
# AttributeError: 'AxesSubplot' object has no attribute 'set_rotation'

# %%
plt.plot(x,PersDF, label = 'Personal')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)

# %%
# t = arange(0.0, 2.0, 0.01)
# s = sin(2.5*pi*t)
# plot(t, s)

# xlabel('time (s)')
# ylabel('voltage (mV)')
# title('Sine Wave')
# grid(True)
# show()

# %%
plt.plot(x,PropDF,label = 'Property')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)
# plt.vlines(7.8, -.5,50000, linestyles='dashed')
# plt.vlines(8.2, -.5,50000, linestyles='dashed')
# plt.annotate('Crime Time',xy=(5.5,35000))

# %%
plt.plot(x,StatDF,label= 'Statutory')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)

# %%
#pivot by month

buckets_month = pd.pivot_table(combined_df,values='Case Number', index='Month',columns='bucket',  aggfunc=lambda x: len(x.unique()),fill_value=0)
buckets_month

# %%
#plot crime by month
OthDF = buckets_month[buckets_month.columns[0]]
PersDF = buckets_month[buckets_month.columns[1]]
PropDF = buckets_month[buckets_month.columns[2]]
StatDF = buckets_month[buckets_month.columns[3]]
x = buckets_month.index.tolist()

plt.plot(x,OthDF,label = 'Others')
plt.plot(x,PersDF,label = 'Personal' )
plt.plot(x,PropDF,label = 'Property')
plt.plot(x,StatDF,label = 'Statutory')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)
plt.title('Temperature and Crime count by months')

plt.tight_layout()

# %%
#pivot by hours
buckets_hour = pd.pivot_table(combined_df,values='Case Number', index='Hour',columns='bucket',  aggfunc=lambda x: len(x.unique()),fill_value=0)
buckets_hour.head()

# %%
#plot by hours
OthDF = buckets_hour[buckets_hour.columns[0]]
PersDF = buckets_hour[buckets_hour.columns[1]]
PropDF = buckets_hour[buckets_hour.columns[2]]
StatDF = buckets_hour[buckets_hour.columns[3]]
x = buckets_hour.index.tolist()

plt.plot(x,OthDF,label = 'Others')
plt.plot(x,PersDF,label = 'Personal' )
plt.plot(x,PropDF,label = 'Property')
plt.plot(x,StatDF,label = 'Statutory')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.xticks(rotation=45)
plt.title('Temperature and Crime count by hours')

plt.tight_layout()

# %%
#pivot by degree and hours
buckets_degree_hour = pd.pivot_table(combined_df,values='Case Number', index='TempBucket',columns='Hour',  aggfunc=lambda x: len(x.unique()),fill_value=0)
buckets_degree_hour.reset_index(drop=False,inplace=True)
buckets_degree_hour

# %%
#why crime is so high in 65 to 74.9 degrees and when that happens?
buckets_degree65 = buckets_degree.loc['65 to 74.9 degrees']
buckets_degree65
